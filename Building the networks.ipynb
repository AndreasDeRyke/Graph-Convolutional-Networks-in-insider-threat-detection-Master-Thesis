# %% [markdown]
# # 4. Create Networks
#
# Once we have our clean dataframe we can build our unweighted network.

# %% [markdown]
# ## 4.1 Load in dataframe

# %%
import pandas as pd
import numpy as np

# %%
Df_connectivity = pd.read_csv('files/DirectMails_clean.csv')

# %%
print(Df_connectivity.shape)
Df_connectivity.head()
# Out:
# (745210, 6)
#                      From                         To                 Date  \
# 0        From_hotmail.com           pallen@enron.com  2001-12-30 10:19:42
# 1  From_mailman.enron.com         k..allen@enron.com  2001-12-27 17:16:46
# 2    no.address@enron.com                To_External  2001-10-18 15:10:12
# 3   ray.alvarez@enron.com          j..kean@enron.com  2001-10-18 14:51:19
# 4   ray.alvarez@enron.com  richard.shapiro@enron.com  2001-10-18 14:51:19
#
#                                              Subject             Message_ID  \
# 0                                Fwd: Bishops Corner  215433951075855374340
# 1  Your Approval is Overdue: Access Request for m...  253634511075855374674
# 2        UPDATE - Supported Internet Email Addresses   89140651075858632242
# 3              Conference Call Today with FERC Staff  317060761075858632278
# 4              Conference Call Today with FERC Staff  317060761075858632278
#
#                                        Interaction
# 0                From_hotmail.com|pallen@enron.com
# 1        From_mailman.enron.com|k..allen@enron.com
# 2                 no.address@enron.com|To_External
# 3          ray.alvarez@enron.com|j..kean@enron.com
# 4  ray.alvarez@enron.com|richard.shapiro@enron.com

# %% [markdown]
# ## 4.2 Determine frequency of every interaction

# %%
# Create new dataframe only storing the connections
Connections = pd.DataFrame()
# Store new variables
Connections[['Address1', 'Address2']] = Df_connectivity.Interaction.str.split('|', expand=True)

# %%
Connections.head()
# Out:
#                  Address1                   Address2
# 0        From_hotmail.com           pallen@enron.com
# 1  From_mailman.enron.com         k..allen@enron.com
# 2    no.address@enron.com                To_External
# 3   ray.alvarez@enron.com          j..kean@enron.com
# 4   ray.alvarez@enron.com  richard.shapiro@enron.com

# %%
# We are interested in how often an interactions occurs
Connections_count = Connections.value_counts().reset_index().rename(columns={0: 'Count'})

# %%
Connections_count.head()
# Out:
#                    Address1                 Address2  Count
# 0      pete.davis@enron.com     pete.davis@enron.com   2413
# 1  vince.kaminski@enron.com               To_aol.com   2206
# 2        kay.mann@enron.com  suzanne.adams@enron.com    870
# 3   jeff.dasovich@enron.com              To_External    865
# 4        kay.mann@enron.com             To_kslaw.com    773

# %%
Connections_count.shape
# Out:
# (57505, 3)

# %% [markdown]
# ## 4.3 Create unweighted network

# %%
import networkx as nx

# %%
# Empty graph
G = nx.Graph()

# %%
# Create lists which stores the connections
e_list = [(Connections_count.Address1[i], Connections_count.Address2.iloc[i]) for i in range(len(Connections_count))]

# %%
# Check result
e_list[:10]
# Out:
# [('pete.davis@enron.com', 'pete.davis@enron.com'),
#  ('vince.kaminski@enron.com', 'To_aol.com'),
#  ('kay.mann@enron.com', 'suzanne.adams@enron.com'),
#  ('jeff.dasovich@enron.com', 'To_External'),
#  ('kay.mann@enron.com', 'To_kslaw.com'),
#  ('jeff.dasovich@enron.com', 'james.steffes@enron.com'),
#  ('jeff.dasovich@enron.com', 'paul.kaufman@enron.com'),
#  ('From_External', 'To_External'),
#  ('jeff.dasovich@enron.com', 'susan.mara@enron.com'),
#  ('jeff.dasovich@enron.com', 'richard.shapiro@enron.com')]

# %%
# Add edges to the graph
G.add_edges_from(e_list)

# %%
# Check if network is fully connected
nx.is_connected(G)
# Out:
# False

# %%
# Get all nodes belonging to different components
nodes_largest_netwerk = sorted(nx.connected_components(G), key=len, reverse=True)[0]
# Extract largest fully connected component
G = G.subgraph(nodes_largest_netwerk)

# %%
# Save graph
nx.write_weighted_edgelist(G, path = 'Files/Intensity_graph')

# %%
# Create a nodelist containing all addresses in the dataset
nodelist = list(G.nodes)

# %%
len(nodelist)
# Out:
# 6533

# %%
# Save graph as adjacency list
nx.write_adjlist(G, path='files/Connectivity_graph')

# %%
# write edgelist
nx.write_edgelist(G, path='files/Connectivity_edge_list.csv')

# %%
# Create adjacency matrix
Connect_adj_matrix = nx.to_pandas_adjacency(G, nodelist, dtype=int)

# %%
print(Connect_adj_matrix.shape)
Connect_adj_matrix
# Out:
# (6533, 6533)
#                                  pete.davis@enron.com  \
# pete.davis@enron.com                                1
# vince.kaminski@enron.com                            0
# To_aol.com                                          0
# kay.mann@enron.com                                  0
# suzanne.adams@enron.com                             0
# ...                                               ...
# jaisinghani@enron.com                               0
# roy.hartstein@enron.com                             0
# roy.steinhagen@enron.com                            0
# s..presas@enron.com                                 0
# didrik.thrane-nielsen@enron.com                     0
#
#                                  vince.kaminski@enron.com  To_aol.com  \
# pete.davis@enron.com                                    0           0
# vince.kaminski@enron.com                                1           1
# To_aol.com                                              1           0
# kay.mann@enron.com                                      0           0
# suzanne.adams@enron.com                                 0           0
# ...                                                   ...         ...
# jaisinghani@enron.com                                   0           0
# roy.hartstein@enron.com                                 0           0
# roy.steinhagen@enron.com                                0           0
# s..presas@enron.com                                     0           0
# didrik.thrane-nielsen@enron.com                         0           0
#
#                                  kay.mann@enron.com  suzanne.adams@enron.com  \
# pete.davis@enron.com                              0                        0
# vince.kaminski@enron.com                          0                        0
# To_aol.com                                        0                        0
# kay.mann@enron.com                                1                        1
# suzanne.adams@enron.com                           1                        0
# ...                                             ...                      ...
# jaisinghani@enron.com                             0                        0
# roy.hartstein@enron.com                           0                        0
# roy.steinhagen@enron.com                          0                        0
# s..presas@enron.com                               1                        0
# didrik.thrane-nielsen@enron.com                   0                        0
#
#                                  jeff.dasovich@enron.com  To_External  \
# pete.davis@enron.com                                   0            0
# vince.kaminski@enron.com                               0            1
# To_aol.com                                             1            0
# kay.mann@enron.com                                     0            1
# suzanne.adams@enron.com                                0            0
# ...                                                  ...          ...
# jaisinghani@enron.com                                  0            0
# roy.hartstein@enron.com                                0            0
# roy.steinhagen@enron.com                               0            0
# s..presas@enron.com                                    0            0
# didrik.thrane-nielsen@enron.com                        0            0
#
#                                  To_kslaw.com  james.steffes@enron.com  \
# pete.davis@enron.com                        0                        0
# vince.kaminski@enron.com                    0                        1
# To_aol.com                                  0                        0
# kay.mann@enron.com                          1                        1
# suzanne.adams@enron.com                     0                        0
# ...                                       ...                      ...
# jaisinghani@enron.com                       0                        0
# roy.hartstein@enron.com                     0                        0
# roy.steinhagen@enron.com                    0                        0
# s..presas@enron.com                         0                        0
# didrik.thrane-nielsen@enron.com             0                        0
#
#                                  paul.kaufman@enron.com  ...  \
# pete.davis@enron.com                                  0  ...
# vince.kaminski@enron.com                              0  ...
# To_aol.com                                            0  ...
# kay.mann@enron.com                                    0  ...
# suzanne.adams@enron.com                               0  ...
# ...                                                 ...  ...
# jaisinghani@enron.com                                 0  ...
# roy.hartstein@enron.com                               0  ...
# roy.steinhagen@enron.com                              0  ...
# s..presas@enron.com                                   0  ...
# didrik.thrane-nielsen@enron.com                       0  ...
#
#                                  sasha.divelbiss@enron.com  \
# pete.davis@enron.com                                     0
# vince.kaminski@enron.com                                 0
# To_aol.com                                               0
# kay.mann@enron.com                                       0
# suzanne.adams@enron.com                                  0
# ...                                                    ...
# jaisinghani@enron.com                                    0
# roy.hartstein@enron.com                                  0
# roy.steinhagen@enron.com                                 0
# s..presas@enron.com                                      0
# didrik.thrane-nielsen@enron.com                          0
#
#                                  louis.allen@enron.com  \
# pete.davis@enron.com                                 0
# vince.kaminski@enron.com                             0
# To_aol.com                                           0
# kay.mann@enron.com                                   0
# suzanne.adams@enron.com                              0
# ...                                                ...
# jaisinghani@enron.com                                0
# roy.hartstein@enron.com                              0
# roy.steinhagen@enron.com                             0
# s..presas@enron.com                                  0
# didrik.thrane-nielsen@enron.com                      0
#
#                                  danny.foster@enron.com  \
# pete.davis@enron.com                                  0
# vince.kaminski@enron.com                              0
# To_aol.com                                            0
# kay.mann@enron.com                                    0
# suzanne.adams@enron.com                               0
# ...                                                 ...
# jaisinghani@enron.com                                 0
# roy.hartstein@enron.com                               0
# roy.steinhagen@enron.com                              0
# s..presas@enron.com                                   0
# didrik.thrane-nielsen@enron.com                       0
#
#                                  grace.taylor@enron.com  rice@enron.com  \
# pete.davis@enron.com                                  0               0
# vince.kaminski@enron.com                              0               0
# To_aol.com                                            0               0
# kay.mann@enron.com                                    0               0
# suzanne.adams@enron.com                               0               0
# ...                                                 ...             ...
# jaisinghani@enron.com                                 0               0
# roy.hartstein@enron.com                               0               0
# roy.steinhagen@enron.com                              0               0
# s..presas@enron.com                                   0               0
# didrik.thrane-nielsen@enron.com                       0               0
#
#                                  jaisinghani@enron.com  \
# pete.davis@enron.com                                 0
# vince.kaminski@enron.com                             0
# To_aol.com                                           0
# kay.mann@enron.com                                   0
# suzanne.adams@enron.com                              0
# ...                                                ...
# jaisinghani@enron.com                                0
# roy.hartstein@enron.com                              0
# roy.steinhagen@enron.com                             0
# s..presas@enron.com                                  0
# didrik.thrane-nielsen@enron.com                      0
#
#                                  roy.hartstein@enron.com  \
# pete.davis@enron.com                                   0
# vince.kaminski@enron.com                               0
# To_aol.com                                             0
# kay.mann@enron.com                                     0
# suzanne.adams@enron.com                                0
# ...                                                  ...
# jaisinghani@enron.com                                  0
# roy.hartstein@enron.com                                0
# roy.steinhagen@enron.com                               0
# s..presas@enron.com                                    0
# didrik.thrane-nielsen@enron.com                        0
#
#                                  roy.steinhagen@enron.com  \
# pete.davis@enron.com                                    0
# vince.kaminski@enron.com                                0
# To_aol.com                                              0
# kay.mann@enron.com                                      0
# suzanne.adams@enron.com                                 0
# ...                                                   ...
# jaisinghani@enron.com                                   0
# roy.hartstein@enron.com                                 0
# roy.steinhagen@enron.com                                0
# s..presas@enron.com                                     0
# didrik.thrane-nielsen@enron.com                         0
#
#                                  s..presas@enron.com  \
# pete.davis@enron.com                               0
# vince.kaminski@enron.com                           0
# To_aol.com                                         0
# kay.mann@enron.com                                 1
# suzanne.adams@enron.com                            0
# ...                                              ...
# jaisinghani@enron.com                              0
# roy.hartstein@enron.com                            0
# roy.steinhagen@enron.com                           0
# s..presas@enron.com                                0
# didrik.thrane-nielsen@enron.com                    0
#
#                                  didrik.thrane-nielsen@enron.com
# pete.davis@enron.com                                           0
# vince.kaminski@enron.com                                       0
# To_aol.com                                                     0
# kay.mann@enron.com                                             0
# suzanne.adams@enron.com                                        0
# ...                                                          ...
# jaisinghani@enron.com                                          0
# roy.hartstein@enron.com                                        0
# roy.steinhagen@enron.com                                       0
# s..presas@enron.com                                            0
# didrik.thrane-nielsen@enron.com                                0
#
# [6533 rows x 6533 columns]

# %%
# Save graph as adjacency matrix
Connect_adj_matrix.to_csv('files/Conn_Adj.csv')

# %% [markdown]
# ## 4.4 Create weighted network

# %%
import networkx as nx

# %%
# Create empty graph
G = nx.Graph()

# %%
# Create an edge list
e_list = [(Connections_count.Address1.iloc[i], Connections_count.Address2.iloc[i], Connections_count.Count.iloc[i]) for i in range(len(Connections_count))]

# %%
e_list[:10]
# Out:
# [('pete.davis@enron.com', 'pete.davis@enron.com', 2413),
#  ('vince.kaminski@enron.com', 'To_aol.com', 2206),
#  ('kay.mann@enron.com', 'suzanne.adams@enron.com', 870),
#  ('jeff.dasovich@enron.com', 'To_External', 865),
#  ('kay.mann@enron.com', 'To_kslaw.com', 773),
#  ('jeff.dasovich@enron.com', 'james.steffes@enron.com', 719),
#  ('jeff.dasovich@enron.com', 'paul.kaufman@enron.com', 707),
#  ('From_External', 'To_External', 706),
#  ('jeff.dasovich@enron.com', 'susan.mara@enron.com', 690),
#  ('jeff.dasovich@enron.com', 'richard.shapiro@enron.com', 678)]

# %%
# Add edges
G.add_weighted_edges_from(e_list)

# %%
# Check if network is fully connected
nx.is_connected(G)
# Out:
# False

# %%
# Get all nodes belonging to different components
nodes_largest_netwerk = sorted(nx.connected_components(G), key=len, reverse=True)[0]
# Extract largest fully connected component
G = G.subgraph(nodes_largest_netwerk)

# %%
# Save graph
nx.write_weighted_edgelist(G, path = 'Files/Intensity_graph')

# %%
# Create a nodelist containing all addresses in the dataset
nodelist = list(G.nodes)

# %%
len(nodelist)
# Out:
# 6533

# %%
# Create adjacency matrix
Intensity_adj_matrix = nx.to_pandas_adjacency(G, nodelist, dtype=float)

# %%
print(Intensity_adj_matrix.shape)
Intensity_adj_matrix
# Out:
# (6533, 6533)
#                                  pete.davis@enron.com  \
# pete.davis@enron.com                           2413.0
# vince.kaminski@enron.com                          0.0
# To_aol.com                                        0.0
# kay.mann@enron.com                                0.0
# suzanne.adams@enron.com                           0.0
# ...                                               ...
# jaisinghani@enron.com                             0.0
# roy.hartstein@enron.com                           0.0
# roy.steinhagen@enron.com                          0.0
# s..presas@enron.com                               0.0
# didrik.thrane-nielsen@enron.com                   0.0
#
#                                  vince.kaminski@enron.com  To_aol.com  \
# pete.davis@enron.com                                  0.0         0.0
# vince.kaminski@enron.com                             61.0      2206.0
# To_aol.com                                         2206.0         0.0
# kay.mann@enron.com                                    0.0         0.0
# suzanne.adams@enron.com                               0.0         0.0
# ...                                                   ...         ...
# jaisinghani@enron.com                                 0.0         0.0
# roy.hartstein@enron.com                               0.0         0.0
# roy.steinhagen@enron.com                              0.0         0.0
# s..presas@enron.com                                   0.0         0.0
# didrik.thrane-nielsen@enron.com                       0.0         0.0
#
#                                  kay.mann@enron.com  suzanne.adams@enron.com  \
# pete.davis@enron.com                            0.0                      0.0
# vince.kaminski@enron.com                        0.0                      0.0
# To_aol.com                                      0.0                      0.0
# kay.mann@enron.com                             30.0                     25.0
# suzanne.adams@enron.com                        25.0                      0.0
# ...                                             ...                      ...
# jaisinghani@enron.com                           0.0                      0.0
# roy.hartstein@enron.com                         0.0                      0.0
# roy.steinhagen@enron.com                        0.0                      0.0
# s..presas@enron.com                             2.0                      0.0
# didrik.thrane-nielsen@enron.com                 0.0                      0.0
#
#                                  jeff.dasovich@enron.com  To_External  \
# pete.davis@enron.com                                 0.0          0.0
# vince.kaminski@enron.com                             0.0        371.0
# To_aol.com                                          31.0          0.0
# kay.mann@enron.com                                   0.0        537.0
# suzanne.adams@enron.com                              0.0          0.0
# ...                                                  ...          ...
# jaisinghani@enron.com                                0.0          0.0
# roy.hartstein@enron.com                              0.0          0.0
# roy.steinhagen@enron.com                             0.0          0.0
# s..presas@enron.com                                  0.0          0.0
# didrik.thrane-nielsen@enron.com                      0.0          0.0
#
#                                  To_kslaw.com  james.steffes@enron.com  \
# pete.davis@enron.com                      0.0                      0.0
# vince.kaminski@enron.com                  0.0                      4.0
# To_aol.com                                0.0                      0.0
# kay.mann@enron.com                      773.0                      2.0
# suzanne.adams@enron.com                   0.0                      0.0
# ...                                       ...                      ...
# jaisinghani@enron.com                     0.0                      0.0
# roy.hartstein@enron.com                   0.0                      0.0
# roy.steinhagen@enron.com                  0.0                      0.0
# s..presas@enron.com                       0.0                      0.0
# didrik.thrane-nielsen@enron.com           0.0                      0.0
#
#                                  paul.kaufman@enron.com  ...  \
# pete.davis@enron.com                                0.0  ...
# vince.kaminski@enron.com                            0.0  ...
# To_aol.com                                          0.0  ...
# kay.mann@enron.com                                  0.0  ...
# suzanne.adams@enron.com                             0.0  ...
# ...                                                 ...  ...
# jaisinghani@enron.com                               0.0  ...
# roy.hartstein@enron.com                             0.0  ...
# roy.steinhagen@enron.com                            0.0  ...
# s..presas@enron.com                                 0.0  ...
# didrik.thrane-nielsen@enron.com                     0.0  ...
#
#                                  sasha.divelbiss@enron.com  \
# pete.davis@enron.com                                   0.0
# vince.kaminski@enron.com                               0.0
# To_aol.com                                             0.0
# kay.mann@enron.com                                     0.0
# suzanne.adams@enron.com                                0.0
# ...                                                    ...
# jaisinghani@enron.com                                  0.0
# roy.hartstein@enron.com                                0.0
# roy.steinhagen@enron.com                               0.0
# s..presas@enron.com                                    0.0
# didrik.thrane-nielsen@enron.com                        0.0
#
#                                  louis.allen@enron.com  \
# pete.davis@enron.com                               0.0
# vince.kaminski@enron.com                           0.0
# To_aol.com                                         0.0
# kay.mann@enron.com                                 0.0
# suzanne.adams@enron.com                            0.0
# ...                                                ...
# jaisinghani@enron.com                              0.0
# roy.hartstein@enron.com                            0.0
# roy.steinhagen@enron.com                           0.0
# s..presas@enron.com                                0.0
# didrik.thrane-nielsen@enron.com                    0.0
#
#                                  danny.foster@enron.com  \
# pete.davis@enron.com                                0.0
# vince.kaminski@enron.com                            0.0
# To_aol.com                                          0.0
# kay.mann@enron.com                                  0.0
# suzanne.adams@enron.com                             0.0
# ...                                                 ...
# jaisinghani@enron.com                               0.0
# roy.hartstein@enron.com                             0.0
# roy.steinhagen@enron.com                            0.0
# s..presas@enron.com                                 0.0
# didrik.thrane-nielsen@enron.com                     0.0
#
#                                  grace.taylor@enron.com  rice@enron.com  \
# pete.davis@enron.com                                0.0             0.0
# vince.kaminski@enron.com                            0.0             0.0
# To_aol.com                                          0.0             0.0
# kay.mann@enron.com                                  0.0             0.0
# suzanne.adams@enron.com                             0.0             0.0
# ...                                                 ...             ...
# jaisinghani@enron.com                               0.0             0.0
# roy.hartstein@enron.com                             0.0             0.0
# roy.steinhagen@enron.com                            0.0             0.0
# s..presas@enron.com                                 0.0             0.0
# didrik.thrane-nielsen@enron.com                     0.0             0.0
#
#                                  jaisinghani@enron.com  \
# pete.davis@enron.com                               0.0
# vince.kaminski@enron.com                           0.0
# To_aol.com                                         0.0
# kay.mann@enron.com                                 0.0
# suzanne.adams@enron.com                            0.0
# ...                                                ...
# jaisinghani@enron.com                              0.0
# roy.hartstein@enron.com                            0.0
# roy.steinhagen@enron.com                           0.0
# s..presas@enron.com                                0.0
# didrik.thrane-nielsen@enron.com                    0.0
#
#                                  roy.hartstein@enron.com  \
# pete.davis@enron.com                                 0.0
# vince.kaminski@enron.com                             0.0
# To_aol.com                                           0.0
# kay.mann@enron.com                                   0.0
# suzanne.adams@enron.com                              0.0
# ...                                                  ...
# jaisinghani@enron.com                                0.0
# roy.hartstein@enron.com                              0.0
# roy.steinhagen@enron.com                             0.0
# s..presas@enron.com                                  0.0
# didrik.thrane-nielsen@enron.com                      0.0
#
#                                  roy.steinhagen@enron.com  \
# pete.davis@enron.com                                  0.0
# vince.kaminski@enron.com                              0.0
# To_aol.com                                            0.0
# kay.mann@enron.com                                    0.0
# suzanne.adams@enron.com                               0.0
# ...                                                   ...
# jaisinghani@enron.com                                 0.0
# roy.hartstein@enron.com                               0.0
# roy.steinhagen@enron.com                              0.0
# s..presas@enron.com                                   0.0
# didrik.thrane-nielsen@enron.com                       0.0
#
#                                  s..presas@enron.com  \
# pete.davis@enron.com                             0.0
# vince.kaminski@enron.com                         0.0
# To_aol.com                                       0.0
# kay.mann@enron.com                               2.0
# suzanne.adams@enron.com                          0.0
# ...                                              ...
# jaisinghani@enron.com                            0.0
# roy.hartstein@enron.com                          0.0
# roy.steinhagen@enron.com                         0.0
# s..presas@enron.com                              0.0
# didrik.thrane-nielsen@enron.com                  0.0
#
#                                  didrik.thrane-nielsen@enron.com
# pete.davis@enron.com                                         0.0
# vince.kaminski@enron.com                                     0.0
# To_aol.com                                                   0.0
# kay.mann@enron.com                                           0.0
# suzanne.adams@enron.com                                      0.0
# ...                                                          ...
# jaisinghani@enron.com                                        0.0
# roy.hartstein@enron.com                                      0.0
# roy.steinhagen@enron.com                                     0.0
# s..presas@enron.com                                          0.0
# didrik.thrane-nielsen@enron.com                              0.0
#
# [6533 rows x 6533 columns]

# %%
Intensity_adj_matrix.to_csv('files/Intensity_Adj.csv')
